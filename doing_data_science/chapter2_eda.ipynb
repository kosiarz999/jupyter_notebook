# %%
import numpy as np
import pandas as pd

# %%
file = pd.read_csv('/home/lukasz/jupyter_notebook/dds_datasets/dds_ch2_nyt/nyt1.csv', sep=',')

# %%
file['age_group'] = pd.cut(file.Age, [-np.inf, 0, 18, 34, 44, 54, 64, np.inf])

# %%
file.age_group
# Out:
# 0         (34.0, 44.0]
# 1          (64.0, inf]
# 2         (18.0, 34.0]
# 3         (44.0, 54.0]
# 4         (44.0, 54.0]
# 5         (44.0, 54.0]
# 6          (-inf, 0.0]
# 7         (44.0, 54.0]
# 8          (0.0, 18.0]
# 9         (44.0, 54.0]
# 10         (-inf, 0.0]
# 11        (18.0, 34.0]
# 12         (-inf, 0.0]
# 13        (54.0, 64.0]
# 14        (18.0, 34.0]
# 15         (-inf, 0.0]
# 16        (34.0, 44.0]
# 17        (18.0, 34.0]
# 18        (34.0, 44.0]
# 19         (-inf, 0.0]
# 20        (54.0, 64.0]
# 21        (54.0, 64.0]
# 22        (44.0, 54.0]
# 23        (18.0, 34.0]
# 24         (-inf, 0.0]
# 25        (18.0, 34.0]
# 26        (18.0, 34.0]
# 27        (44.0, 54.0]
# 28        (44.0, 54.0]
# 29        (18.0, 34.0]
#               ...
# 458411    (54.0, 64.0]
# 458412     (64.0, inf]
# 458413     (-inf, 0.0]
# 458414    (18.0, 34.0]
# 458415    (34.0, 44.0]
# 458416    (18.0, 34.0]
# 458417    (34.0, 44.0]
# 458418    (54.0, 64.0]
# 458419    (44.0, 54.0]
# ...

# %%
file
# Out:
#         Age  Gender  Impressions  Clicks  Signed_In     age_group
# 0        36       0            3       0          1  (34.0, 44.0]
# 1        73       1            3       0          1   (64.0, inf]
# 2        30       0            3       0          1  (18.0, 34.0]
# 3        49       1            3       0          1  (44.0, 54.0]
# 4        47       1           11       0          1  (44.0, 54.0]
# 5        47       0           11       1          1  (44.0, 54.0]
# 6         0       0            7       1          0   (-inf, 0.0]
# 7        46       0            5       0          1  (44.0, 54.0]
# 8        16       0            3       0          1   (0.0, 18.0]
# 9        52       0            4       0          1  (44.0, 54.0]
# 10        0       0            8       1          0   (-inf, 0.0]
# 11       21       0            3       0          1  (18.0, 34.0]
# 12        0       0            4       0          0   (-inf, 0.0]
# ...
